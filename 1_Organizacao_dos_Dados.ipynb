# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# import tensorflow as tf

# %%
direct = "C:/Users/admin/Desktop/EMG_IA_LIT GITHUB/EMG_IA_LIT/EMG-LIT" # Cole o diretório da pasta ./EMG_2Chs aqui

# %%
# Diretório onde estão as pastas de classificação
classification_directory = direct + '/EMG-S1'
print(classification_directory)

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset1 = pd.concat(dataframes, ignore_index=True)
# Out:
# C:/Users/admin/Desktop/EMG_IA_LIT GITHUB/EMG_IA_LIT/EMG-LIT/EMG-S1

# %%
# HC
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/HC'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta HC
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_HC_1 = dataframes[0]
df_HC_2 = dataframes[1]
df_HC_3 = dataframes[2]
df_HC_4 = dataframes[3]
df_HC_5 = dataframes[4]
df_HC_6 = dataframes[5]

# %%
# I
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/I'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta I
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Se desejar, você pode acessar cada DataFrame individualmente, por exemplo:
df_I_1 = dataframes[0]
df_I_2 = dataframes[1]
df_I_3 = dataframes[2]
df_I_4 = dataframes[3]
df_I_5 = dataframes[4]
df_I_6 = dataframes[5]
# ... e assim por diante

# %%
# L
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/L'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta L
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_L_1 = dataframes[0]
df_L_2 = dataframes[1]
df_L_3 = dataframes[2]
df_L_4 = dataframes[3]
df_L_5 = dataframes[4]
df_L_6 = dataframes[5]

# %%
# M
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/M'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta HC
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_M_1 = dataframes[0]
df_M_2 = dataframes[1]
df_M_3 = dataframes[2]
df_M_4 = dataframes[3]
df_M_5 = dataframes[4]
df_M_6 = dataframes[5]

# %%
# R
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/R'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta R
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_R_1 = dataframes[0]
df_R_2 = dataframes[1]
df_R_3 = dataframes[2]
df_R_4 = dataframes[3]
df_R_5 = dataframes[4]
df_R_6 = dataframes[5]

# %%
# T-I
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/T-I'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta HC
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_TI_1 = dataframes[0]
df_TI_2 = dataframes[1]
df_TI_3 = dataframes[2]
df_TI_4 = dataframes[3]
df_TI_5 = dataframes[4]
df_TI_6 = dataframes[5]

# %%
# T-L
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/T-L'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta HC
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_TL_1 = dataframes[0]
df_TL_2 = dataframes[1]
df_TL_3 = dataframes[2]
df_TL_4 = dataframes[3]
df_TL_5 = dataframes[4]
df_TL_6 = dataframes[5]

# %%
# T-M
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/T-M'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta T-M
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_TM_1 = dataframes[0]
df_TM_2 = dataframes[1]
df_TM_3 = dataframes[2]
df_TM_4 = dataframes[3]
df_TM_5 = dataframes[4]
df_TM_6 = dataframes[5]

# %%
# T-R
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/T-R'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta T-R
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_TR_1 = dataframes[0]
df_TR_2 = dataframes[1]
df_TR_3 = dataframes[2]
df_TR_4 = dataframes[3]
df_TR_5 = dataframes[4]
df_TR_6 = dataframes[5]

# %%
# Diretório onde os arquivos CSV estão localizados
diretorio = direct + '/EMG-S1/T-T'

# Lista para armazenar os DataFrames
dataframes = []

# Iterar sobre os arquivos na pasta
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Ler o arquivo CSV e armazenar em um DataFrame
        df = pd.read_csv(caminho_arquivo)
        
        # Adicionar o DataFrame à lista
        dataframes.append(df)

# Agora, você tem uma lista de DataFrames, cada um correspondendo a um arquivo CSV na pasta T-T
# Os DataFrames estão armazenados na ordem em que os arquivos foram lidos

# Armazenando cada dataframe individualmente
df_TT_1 = dataframes[0]
df_TT_2 = dataframes[1]
df_TT_3 = dataframes[2]
df_TT_4 = dataframes[3]
df_TT_5 = dataframes[4]
df_TT_6 = dataframes[5]
