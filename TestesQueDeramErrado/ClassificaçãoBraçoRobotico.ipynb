# %%
from google.colab import drive
drive.mount('/EMG_2Chs')
# Out:
# Drive already mounted at /EMG_2Chs; to attempt to forcibly remount, call drive.mount("/EMG_2Chs", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

# %% [markdown]
# # Armazenando os dados em um dataset

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S1' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset1 = pd.concat(dataframes, ignore_index=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Diretório onde estão as pastas de classificação

classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S2' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação

try:
    for classification_folder in os.listdir(classification_directory):
        classification_path = os.path.join(classification_directory, classification_folder)
        # Resto do seu código aqui

        # Verifica se é uma pasta (ignora arquivos)
        if os.path.isdir(classification_path):
            # Loop pelos arquivos CSV na pasta de classificação
            for filename in os.listdir(classification_path):
                if filename.endswith('.csv'):
                    file_path = os.path.join(classification_path, filename)
                    df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                    # Adiciona o DataFrame à lista
                    dataframes.append(df)
    dataset2 = pd.concat(dataframes, ignore_index=True)
except OSError as e:
    print(f"Erro ao acessar o diretório: {e}")




# Concatena todos os DataFrames em um único DataFrame "dataset"

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S3' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset3 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S4' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset4 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S5' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset5 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S6' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset6 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S7' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset7 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S8' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset8 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S9' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset9 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset10 = pd.concat(dataframes, ignore_index=True)

# %%
dataset9
# Out:
#              EMG1      EMG2  class  user
# 0        0.000556  0.000319      4     8
# 1        0.000516  0.000388      4     8
# 2        0.000469  0.000418      4     8
# 3        0.000415  0.000416      4     8
# 4        0.000354  0.000392      4     8
# ...           ...       ...    ...   ...
# 1199995 -0.000086  0.000306      0     8
# 1199996 -0.000073  0.000309      0     8
# 1199997 -0.000063  0.000306      0     8
# 1199998 -0.000056  0.000299      0     8
# 1199999 -0.000048  0.000289      0     8
#
# [1200000 rows x 4 columns]

# %%
for i in range(1, 11):
  datastring = "dataset" + str(i)
  print(datastring)
# Out:
# dataset1
# dataset2
# dataset3
# dataset4
# dataset5
# dataset6
# dataset7
# dataset8
# dataset9
# dataset10

# %%
# Suponha que você tenha seus DataFrames como dataset1, dataset2, ..., dataset10

# Crie uma lista com todos os DataFrames
dataframes = [dataset1, dataset2, dataset3, dataset4, dataset5, dataset6, dataset7, dataset8, dataset9, dataset10]

# Concatene todos os DataFrames em um único DataFrame
dataset_final = pd.concat(dataframes, ignore_index=True)

# O argumento 'ignore_index=True' redefinirá os índices do DataFrame resultante

# Agora, 'dataset_final' conterá todos os dados dos DataFrames concatenados em um único DataFrame.

dataset_final.head()
# Out:
#        EMG1      EMG2 class user
# 0  0.000225  0.000439     6    1
# 1  0.000745  0.000475     6    1
# 2  0.001311  0.000511     6    1
# 3  0.001803  0.000538     6    1
# 4  0.002117  0.000554     6    1

# %%
tamanho = dataset_final.shape  # Retorna uma tupla (número de linhas, número de colunas)
print("Número de Linhas:", tamanho[0])
print("Número de Colunas:", tamanho[1])
# Out:
# Número de Linhas: 12020000
# Número de Colunas: 4

# %%
dataset_final
# Out:
#               EMG1      EMG2 class user
# 0         0.000225  0.000439     6    1
# 1         0.000745  0.000475     6    1
# 2         0.001311  0.000511     6    1
# 3         0.001803  0.000538     6    1
# 4         0.002117  0.000554     6    1
# ...            ...       ...   ...  ...
# 12019995 -0.000279 -0.000633     0    9
# 12019996 -0.000234 -0.000595     0    9
# 12019997 -0.000212 -0.000512     0    9
# 12019998 -0.000220 -0.000415     0    9
# 12019999 -0.000250 -0.000329     0    9
#
# [12020000 rows x 4 columns]

# %%
# Embaralhe o DataFrame
data = dataset_final.sample(frac=1, random_state=42).reset_index(drop=True)

# O argumento 'frac=1' significa que você deseja amostrar 100% das linhas, ou seja, embaralhar todas as linhas.
# O argumento 'random_state' é usado para garantir que o embaralhamento seja reproduzível.

# Agora, 'data' conterá os dados embaralhados.

# %%
tt = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/T-R/T-R6.csv')
tt.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000227 -0.000074      8     9
# 1  0.000187 -0.000065      8     9
# 2  0.000167 -0.000066      8     9
# 3  0.000164 -0.000073      8     9
# 4  0.000163 -0.000080      8     9

# %%
hc1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/HC/HC-6.csv')
hc1.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000199 -0.000151      0     9
# 1  0.000197 -0.000103      0     9
# 2  0.000183 -0.000060      0     9
# 3  0.000150 -0.000031      0     9
# 4  0.000098 -0.000023      0     9

# %%
tr = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/T-R/T-R6.csv')
tr.head(100)
# Out:
#         EMG1      EMG2  class  user
# 0   0.000227 -0.000074      8     9
# 1   0.000187 -0.000065      8     9
# 2   0.000167 -0.000066      8     9
# 3   0.000164 -0.000073      8     9
# 4   0.000163 -0.000080      8     9
# ..       ...       ...    ...   ...
# 95 -0.000012  0.000432      8     9
# 96 -0.000050  0.000440      8     9
# 97 -0.000094  0.000390      8     9
# 98 -0.000133  0.000293      8     9
# 99 -0.000159  0.000172      8     9
#
# [100 rows x 4 columns]

# %%
tr = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S9/HC/HC-1.csv')
tr.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000178 -0.000261      0     8
# 1  0.000211 -0.000318      0     8
# 2  0.000229 -0.000373      0     8
# 3  0.000236 -0.000418      0     8
# 4  0.000240 -0.000442      0     8

# %%
hc = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S8/HC/HC-1.csv')
hc.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000028  0.000749      0     7
# 1  0.000033  0.000750      0     7
# 2  0.000027  0.000719      0     7
# 3  0.000028  0.000648      0     7
# 4  0.000044  0.000539      0     7

# %%
tt.iloc[0][3]
# Out:
# 9.0

# %%
hc = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/HC/HC-1.csv')
hc.head()
# Out:
#        EMG1      EMG2  class  user
# 0 -0.000170  0.000204      0     9
# 1 -0.000141  0.000134      0     9
# 2 -0.000146  0.000081      0     9
# 3 -0.000182  0.000059      0     9
# 4 -0.000234  0.000079      0     9

# %% [markdown]
# # Helper Functions (Funções auxiliares)

# %%
def onehot_encode(df, column):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=column)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
def preprocess_inputs(df, target='class'):
    df = df.copy()

    # One-hot encode whichever target column is not being used
    targets = ['class', 'user']
    targets.remove(target)
    df = onehot_encode(df, column=targets[0])

    # Split df into X and y
    y = df[target].copy()
    X = df.drop(target, axis=1)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=123)

    # Scale X with a standard scaler
    scaler = StandardScaler()
    scaler.fit(X_train)

    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

    return X_train, X_test, y_train, y_test

# %%
def build_model(num_classes=10):

    inputs = tf.keras.Input(shape=(X_train.shape[1],))
    x = tf.keras.layers.Dense(128, activation='relu')(inputs)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# # Predicting Hand Movement Class (Aula de previsão de movimento da mão)

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data, target='class')
# Out:
# <ipython-input-51-b1b73a166137>:3: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   dummies = pd.get_dummies(df[column], prefix=column)

# %%
y_train
# Out:
# 10562356    2
# 5732571     8
# 2760252     1
# 9929561     5
# 1470438     5
#            ..
# 1241052     3
# 11552066    2
# 4222334     1
# 8666477     9
# 4967934     0
# Name: class, Length: 10818000, dtype: object

# %%
y_train.value_counts()
# Out:
# 0    1116372
# 5    1080422
# 7    1080392
# 8    1080128
# 1    1080043
# 3    1079929
# 9    1079812
# 2    1079715
# 4    1079362
# 6    1061825
# Name: class, dtype: int64

# %%
X_train.value_counts()
# Out:
# EMG1       EMG2       user_0     user_1     user_2     user_3     user_4     user_5     user_6     user_7     user_8     user_9
# -0.090871  -0.087442  -0.329884  -0.332935  -0.333097  -0.332952  -0.333034  -0.332982  -0.333128  -0.333121   3.002835  -0.339140    6
#  0.096108   0.162241  -0.329884  -0.332935  -0.333097  -0.332952  -0.333034  -0.332982  -0.333128  -0.333121   3.002835  -0.339140    5
#  0.053689   0.087633  -0.329884  -0.332935  -0.333097  -0.332952  -0.333034  -0.332982  -0.333128  -0.333121   3.002835  -0.339140    5
#  0.142155  -0.056497  -0.329884  -0.332935  -0.333097  -0.332952  -0.333034  -0.332982  -0.333128  -0.333121   3.002835  -0.339140    5
#  0.005688   0.291534  -0.329884  -0.332935  -0.333097  -0.332952  -0.333034  -0.332982  -0.333128  -0.333121   3.002835  -0.339140    5
#                                                                                                                                      ..
# ...

# %%
X_train.shape[1]
# Out:
# 12

# %%
print("Dimensões de X_train:", X_train.shape)
print("Dimensões de y_train:", y_train.shape)
# Out:
# Dimensões de X_train: (10818000, 12)
# Dimensões de y_train: (10818000,)

# %%
unique_classes = pd.unique(y_train)
print("Classes únicas:", unique_classes)
# Out:
# Classes únicas: [2 8 1 5 6 3 9 4 0 7]

# %%
# Converter y_train para o tipo correto
y_train = tf.convert_to_tensor(y_train, dtype=tf.int32)

# %%
"""class_model = build_model(num_classes=10)

class_history = class_model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)"""
# Out:
# "class_model = build_model(num_classes=10)\n\nclass_history = class_model.fit(\n    X_train,\n    y_train,\n    validation_split=0.2,\n    batch_size=32,\n    epochs=5,\n    callbacks=[\n        tf.keras.callbacks.EarlyStopping(\n            monitor='val_loss',\n            patience=3,\n            restore_best_weights=True\n        )\n    ]\n)"

# %% [markdown]
# # Classificando os dados

# %% [markdown]
# a cédula abaixo é a que é pra testar no computador da Nath
# *ATENÇÃO, lembrar de mudar os dados para 70%

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Melhor valor de alpha: 3.359818286283788e-07
# Acurácia no conjunto de teste: 0.15

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Melhor valor de alpha: 3.359818286283788e-07
# Acurácia no conjunto de teste: 0.15
# Tempo total de execução: 458.46 segundos

# %%
# ESTÁ AQUI

from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np
import time

def print_progress(iteration, total, accuracy=None, elapsed_time=None):
    # Esta função imprime informações de progresso a cada segundo
    if elapsed_time is not None:
        print(f"Iteração {iteration}/{total} - Acurácia: {accuracy:.2f} - Tempo decorrido: {elapsed_time:.1f} segundos")
    else:
        print(f"Iteração {iteration}/{total}")

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=11, n_jobs=-1, verbose=2)

# Inicie a contagem de tempo
start_time = time.time()

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Calcule o tempo gasto na pesquisa em grade
elapsed_time = time.time() - start_time

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator()

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')

# Exiba o tempo total gasto
print(f'Tempo total de execução: {elapsed_time:.2f} segundos')
# Out:
# Fitting 11 folds for each of 20 candidates, totalling 220 fits
# Melhor valor de alpha: 1.438449888287663e-06
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-4fd5b1b4d6a7> in <cell line: 43>()
#      41
#      42 # Obtenha o melhor modelo treinado com os melhores hiperparâmetros
# ---> 43 best_nb_model = grid_search.best_estimator()
#      44
#      45 # Avalie o modelo no conjunto de teste
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator'

# %% [markdown]
# **Testando os códigos**

# %% [markdown]
# *Com os dados de treinamento em 70%*

# %% [markdown]
# Aumentando o cross-validation  pra "cv=7"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=7, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')

# %% [markdown]
# Aumentando o cross-validation pra "cv=9"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=9, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 9 folds for each of 20 candidates, totalling 180 fits
# Melhor valor de alpha: 6.158482110660267e-06
# Acurácia no conjunto de teste: 0.15
# Tempo total de execução: 718.35 segundos

# %% [markdown]
# Aumentando o cross-validation pra "cv=11"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=11, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 11 folds for each of 20 candidates, totalling 220 fits
# Melhor valor de alpha: 1.438449888287663e-06
# Acurácia no conjunto de teste: 0.15
# Tempo total de execução: 870.13 segundos

# %% [markdown]
# *Teste com os dados de treinamento em 90%*

# %% [markdown]
# Aumentando o cross-validation pra "cv=7"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=7, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 7 folds for each of 20 candidates, totalling 140 fits

# %% [markdown]
# Aumentando o cross-validation pra "cv=9"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=9, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')

# %% [markdown]
# Aumentando o cross-validation pra "cv=11"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=11, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
