# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd

# %%
# Diretório onde estão as pastas de classificação
classification_directory = "C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S1"

 # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset1 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação

classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S2' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação

try:
    for classification_folder in os.listdir(classification_directory):
        classification_path = os.path.join(classification_directory, classification_folder)
        # Resto do seu código aqui

        # Verifica se é uma pasta (ignora arquivos)
        if os.path.isdir(classification_path):
            # Loop pelos arquivos CSV na pasta de classificação
            for filename in os.listdir(classification_path):
                if filename.endswith('.csv'):
                    file_path = os.path.join(classification_path, filename)
                    df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                    # Adiciona o DataFrame à lista
                    dataframes.append(df)
    dataset2 = pd.concat(dataframes, ignore_index=True)
except OSError as e:
    print(f"Erro ao acessar o diretório: {e}")




# Concatena todos os DataFrames em um único DataFrame "dataset"

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S3' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset3 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S4' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset4 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S5' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset5 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S6' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset6 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S7' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset7 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S8' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset8 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S9' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset9 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = 'C:/Users/Nathaly/OneDrive - IFRN/2023/LIT/EMG_2Chs/EMG-S10' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset10 = pd.concat(dataframes, ignore_index=True)

# %%
dataset3
# Out:
#              EMG1      EMG2  class  user
# 0        0.000289  0.000016      0     2
# 1        0.000194  0.000047      0     2
# 2        0.000011  0.000061      0     2
# 3       -0.000228  0.000067      0     2
# 4       -0.000460  0.000067      0     2
# ...           ...       ...    ...   ...
# 1199995 -0.000142 -0.000080      9     2
# 1199996 -0.000166 -0.000070      9     2
# 1199997 -0.000192 -0.000053      9     2
# 1199998 -0.000224 -0.000029      9     2
# 1199999 -0.000255  0.000003      9     2
#
# [1200000 rows x 4 columns]

# %%
dataframes
# Out:
# [           EMG1      EMG2  class  user
#  0     -0.000170  0.000204      0     9
#  1     -0.000141  0.000134      0     9
#  2     -0.000146  0.000081      0     9
#  3     -0.000182  0.000059      0     9
#  4     -0.000234  0.000079      0     9
#  ...         ...       ...    ...   ...
#  19995 -0.000279 -0.000633      0     9
#  19996 -0.000234 -0.000595      0     9
#  19997 -0.000212 -0.000512      0     9
#  19998 -0.000220 -0.000415      0     9
#  19999 -0.000250 -0.000329      0     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.
9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000061  0.000377      3     9
#  1      0.000010  0.000347      3     9
#  2     -0.000036  0.000325      3     9
#  3     -0.000081  0.000300      3     9
#  4     -0.000137  0.000261      3     9
#  ...         ...       ...    ...   ...
#  19995  0.000123  0.000166      3     9
#  19996  0.000177  0.000166      3     9
#  19997  0.000204  0.000159      3     9
#  19998  0.000214  0.000149      3     9
#  19999  0.000214  0.000145      3     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000017  0.000019      3     9
#  1     -0.000013 -0.000016      3     9
#  2     -0.000005 -0.000053      3     9
#  3     -0.000002 -0.000085      3     9
#  4     -0.000006 -0.000108      3     9
#  ...         ...       ...    ...   ...
#  19995 -0.000237 -0.000111      3     9
#  19996 -0.000142 -0.000125      3     9
#  19997 -0.000043 -0.000156      3     9
#  19998  0.000040 -0.000190      3     9
#  19999  0.000106 -0.000213      3     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000502  0.000939      4     9
#  1     -0.000600  0.000879      4     9
#  2     -0.000649  0.000792      4     9
#  3     -0.000642  0.000689      4     9
#  4     -0.000585  0.000588      4     9
#  ...         ...       ...    ...   ...
#  19995  0.000624  0.000073      4     9
#  19996  0.000672  0.000098      4     9
#  19997  0.000724  0.000123      4     9
#  19998  0.000770  0.000136      4     9
#  19999  0.000793  0.000141      4     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000206 -0.000004      4     9
#  1     -0.000149  0.000015      4     9
#  2     -0.000106  0.000040      4     9
#  3     -0.000077  0.000074      4     9
#  4     -0.000056  0.000114      4     9
#  ...         ...       ...    ...   ...
#  19995 -0.000333  0.000032      4     9
#  19996 -0.000421  0.000048      4     9
#  19997 -0.000474  0.000068      4     9
#  19998 -0.000497  0.000086      4     9
#  19999 -0.000500  0.000102      4     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000490 -0.000549      4     9
#  1     -0.000466 -0.000482      4     9
#  2     -0.000432 -0.000390      4     9
#  3     -0.000397 -0.000286      4     9
#  4     -0.000367 -0.000181      4     9
#  ...         ...       ...    ...   ...
#  19995 -0.000003 -0.000192      4     9
#  19996  0.000002 -0.000171      4     9
#  19997 -0.000011 -0.000142      4     9
#  19998 -0.000061 -0.000117      4     9
#  19999 -0.000148 -0.000112      4     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000495 -0.000224      4     9
#  1     -0.000497 -0.000214      4     9
#  2     -0.000475 -0.000192      4     9
#  3     -0.000427 -0.000172      4     9
#  4     -0.000347 -0.000165      4     9
#  ...         ...       ...    ...   ...
#  19995  0.000189 -0.000136      4     9
#  19996  0.000088 -0.000107      4     9
#  19997 -0.000056 -0.000089      4     9
#  19998 -0.000227 -0.000090      4     9
#  19999 -0.000393 -0.000109      4     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000158  0.000093      4     9
#  1      0.000110  0.000096      4     9
#  2      0.000065  0.000107      4     9
#  3      0.000033  0.000118      4     9
#  4      0.000018  0.000121      4     9
#  ...         ...       ...    ...   ...
#  19995 -0.000129 -0.000064      4     9
#  19996 -0.000156 -0.000063      4     9
#  19997 -0.000186 -0.000055      4     9
#  19998 -0.000215 -0.000042      4     9
#  19999 -0.000230 -0.000027      4     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.
9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000109  0.000030      6     9
#  1      0.000103  0.000041      6     9
#  2      0.000124  0.000048      6     9
#  3      0.000162  0.000046      6     9
#  4      0.000206  0.000037      6     9
#  ...         ...       ...    ...   ...
#  19995  0.000360 -0.000046      6     9
#  19996  0.000351 -0.000014      6     9
#  19997  0.000324  0.000006      6     9
#  19998  0.000276  0.000013      6     9
#  19999  0.000215  0.000014      6     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000433 -0.000082      6     9
#  1      0.000204 -0.000091      6     9
#  2     -0.000077 -0.000102      6     9
#  3     -0.000367 -0.000108      6     9
#  4     -0.000613 -0.000106      6     9
#  ...         ...       ...    ...   ...
#  19995 -0.000038 -0.000062      6     9
#  19996 -0.000066 -0.000084      6     9
#  19997 -0.000099 -0.000111      6     9
#  19998 -0.000135 -0.000131      6     9
#  19999 -0.000168 -0.000136      6     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000400  0.000055      6     9
#  1      0.000379  0.000081      6     9
#  2      0.000321  0.000103      6     9
#  3      0.000232  0.000121      6     9
#  4      0.000129  0.000134      6     9
#  ...         ...       ...    ...   ...
#  19995  0.000143  0.000169      6     9
#  19996  0.000153  0.000155      6     9
#  19997  0.000163  0.000144      6     9
#  19998  0.000175  0.000136      6     9
#  19999  0.000192  0.000126      6     9
#
#  [20000 rows x 4 columns],
#             EMG1          EMG2  class  user
#  0      0.000313  6.995045e-05      6     9
#  1      0.000306  4.402000e-05      6     9
#  2      0.000289  1.808955e-05      6     9
#  3      0.000265  3.341602e-06      6     9
#  4      0.000234 -5.479652e-07      6     9
#  ...         ...           ...    ...   ...
#  19995 -0.001296  5.795762e-05      6     9
#  19996 -0.001384  3.688912e-05      6     9
#  19997 -0.001404  2.165498e-05      6     9
#  19998 -0.001376  1.776542e-05      6     9
#  19999 -0.001325  2.408596e-05      6     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000232  0.000081      6     9
#  1      0.000280  0.000081      6     9
#  2      0.000351  0.000088      6     9
#  3      0.000434  0.000102      6     9
#  4      0.000512  0.000120      6     9
#  ...         ...       ...    ...   ...
#  19995 -0.000143  0.000057      6     9
#  19996 -0.000074  0.000076      6     9
#  19997 -0.000025  0.000092      6     9
#  19998  0.000014  0.000095      6     9
#  19999  0.000062  0.000084      6     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000001  0.000176      6     9
#  1      0.000030  0.000161      6     9
#  2      0.000061  0.000148      6     9
#  3      0.000094  0.000141      6     9
#  4      0.000126  0.000138      6     9
#  ...         ...       ...    ...   ...
#  19995 -0.000021  0.000039      6     9
#  19996 -0.000014  0.000051      6     9
#  19997  0.000017  0.000068      6     9
#  19998  0.000069  0.000082      6     9
#  19999  0.000130  0.000091      6     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000118  0.000206      7     9
#  1      0.000086  0.000202      7     9
#  2      0.000035  0.000189      7     9
#  3     -0.000013  0.000173      7     9
#  4     -0.000047  0.000165      7     9
#  ...         ...       ...    ...   ...
#  19995 -0.000621  0.000055      7     9
#  19996 -0.000701  0.000084      7     9
#  19997 -0.000752  0.000092      7     9
#  19998 -0.000770  0.000080      7     9
#  19999 -0.000739  0.000055      7     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000058  0.000062      7     9
#  1      0.000116  0.000043      7     9
#  2      0.000149  0.000025      7     9
#  3      0.000146  0.000007      7     9
#  4      0.000117 -0.000007      7     9
#  ...         ...       ...    ...   ...
#  19995  0.000263 -0.000117      7     9
#  19996  0.000209 -0.000090      7     9
#  19997  0.000147 -0.000060      7     9
#  19998  0.000078 -0.000040      7     9
#  19999  0.000006 -0.000035      7     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000085 -0.000111      7     9
#  1     -0.000091 -0.000091      7     9
#  2     -0.000107 -0.000079      7     9
#  3     -0.000123 -0.000076      7     9
#  4     -0.000132 -0.000078      7     9
#  ...         ...       ...    ...   ...
#  19995 -0.000066 -0.000203      7     9
#  19996 -0.000020 -0.000208      7     9
#  19997  0.000035 -0.000204      7     9
#  19998  0.000098 -0.000199      7     9
#  19999  0.000159 -0.000199      7     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000037  0.000007      7     9
#  1      0.000027  0.000009      7     9
#  2      0.000011  0.000003      7     9
#  3     -0.000003 -0.000006      7     9
#  4     -0.000008 -0.000016      7     9
#  ...         ...       ...    ...   ...
#  19995  0.000074 -0.000143      7     9
#  19996  0.000017 -0.000138      7     9
#  19997 -0.000048 -0.000133      7     9
#  19998 -0.000122 -0.000114      7     9
#  19999 -0.000192 -0.000069      7     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000308  0.000081      7     9
#  1      0.000302  0.000083      7     9
#  2      0.000311  0.000082      7     9
#  3      0.000329  0.000084      7     9
#  4      0.000340  0.000091      7     9
#  ...         ...       ...    ...   ...
#  19995  0.000237  0.000029      7     9
#  19996  0.000224  0.000038      7     9
#  19997  0.000206  0.000049      7     9
#  19998  0.000179  0.000060      7     9
#  19999  0.000147  0.000070      7     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000111 -0.000112      7     9
#  1      0.000070 -0.000003      7     9
#  2     -0.000014  0.000076      7     9
#  3     -0.000136  0.000119      7     9
#  4     -0.000281  0.000127      7     9
#  ...         ...       ...    ...   ...
#  19995  0.000372  0.000041      7     9
#  19996  0.000351  0.000031      7     9
#  19997  0.000279  0.000026      7     9
#  19998  0.000166  0.000030      7     9
#  19999  0.000033  0.000048      7     9
#
#  [20000 rows x 4 columns],
#             EMG1          EMG2  class  user
#  0      0.000422 -2.203085e-04      8     9
#  1      0.000425 -2.451045e-04      8     9
#  2      0.000412 -2.561249e-04      8     9
#  3      0.000387 -2.611490e-04      8     9
#  4      0.000356 -2.677937e-04      8     9
#  ...         ...           ...    ...   ...
#  19995  0.000027  1.176900e-05      8     9
#  19996  0.000041 -5.479652e-07      8     9
#  19997  0.000059 -1.691656e-05      8     9
#  19998  0.000074 -3.020592e-05      8     9
#  19999  0.000088 -3.782299e-05      8     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000223 -0.000122      8     9
#  1      0.000238 -0.000126      8     9
#  2      0.000248 -0.000131      8     9
#  3      0.000249 -0.000132      8     9
#  4      0.000239 -0.000121      8     9
#  ...         ...       ...    ...   ...
#  19995  0.000052 -0.000537      8     9
#  19996  0.000043 -0.000578      8     9
#  19997  0.000035 -0.000612      8     9
#  19998  0.000025 -0.000632      8     9
#  19999  0.000010 -0.000640      8     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000139 -0.000099      8     9
#  1     -0.000181 -0.000068      8     9
#  2     -0.000223 -0.000033      8     9
#  3     -0.000255 -0.000005      8     9
#  4     -0.000271  0.000003      8     9
#  ...         ...       ...    ...   ...
#  19995  0.000109  0.000150      8     9
#  19996  0.000074  0.000182      8     9
#  19997  0.000053  0.000210      8     9
#  19998  0.000035  0.000232      8     9
#  19999  0.000007  0.000245      8     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000118 -0.000260      8     9
#  1     -0.000128 -0.000267      8     9
#  2     -0.000134 -0.000254      8     9
#  3     -0.000136 -0.000228      8     9
#  4     -0.000137 -0.000200      8     9
#  ...         ...       ...    ...   ...
#  19995  0.000007  0.000450      8     9
#  19996 -0.000037  0.000218      8     9
#  19997 -0.000049  0.000016      8     9
#  19998 -0.000019 -0.000132      8     9
#  19999  0.000043 -0.000221      8     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000372  0.000017      8     9
#  1     -0.000422 -0.000032      8     9
#  2     -0.000464 -0.000087      8     9
#  3     -0.000493 -0.000134      8     9
#  4     -0.000508 -0.000162      8     9
#  ...         ...       ...    ...   ...
#  19995 -0.000049  0.000407      8     9
#  19996 -0.000125  0.000370      8     9
#  19997 -0.000186  0.000327      8     9
#  19998 -0.000223  0.000281      8     9
#  19999 -0.000231  0.000228      8     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000227 -0.000074      8     9
#  1      0.000187 -0.000065      8     9
#  2      0.000167 -0.000066      8     9
#  3      0.000164 -0.000073      8     9
#  4      0.000163 -0.000080      8     9
#  ...         ...       ...    ...   ...
#  19995 -0.000108 -0.000168      8     9
#  19996 -0.000140 -0.000317      8     9
#  19997 -0.000148 -0.000390      8     9
#  19998 -0.000131 -0.000365      8     9
#  19999 -0.000089 -0.000266      8     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000287  0.000128      9     9
#  1      0.000267  0.000102      9     9
#  2      0.000216  0.000082      9     9
#  3      0.000139  0.000081      9     9
#  4      0.000045  0.000104      9     9
#  ...         ...       ...    ...   ...
#  19995 -0.000039 -0.000046      9     9
#  19996 -0.000040 -0.000023      9     9
#  19997 -0.000020  0.000009      9     9
#  19998  0.000011  0.000035      9     9
#  19999  0.000041  0.000052      9     9
#
#  [20000 rows x 4 columns],
#             EMG1          EMG2  class  user
#  0      0.000113  5.341978e-05      9     9
#  1      0.000080  6.606088e-05      9     9
#  2      0.000050  8.275361e-05      9     9
#  3      0.000037  1.022014e-04      9     9
#  4      0.000055  1.205148e-04      9     9
#  ...         ...           ...    ...   ...
#  19995  0.000079 -6.868512e-06      9     9
#  19996  0.000069 -2.238345e-07      9     9
#  19997 -0.000002  2.959618e-05      9     9
#  19998 -0.000145  6.897806e-05      9     9
#  19999 -0.000352  1.036600e-04      9     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000168  0.000061      9     9
#  1     -0.000223  0.000043      9     9
#  2     -0.000313  0.000039      9     9
#  3     -0.000426  0.000051      9     9
#  4     -0.000535  0.000077      9     9
#  ...         ...       ...    ...   ...
#  19995  0.000021  0.000162      9     9
#  19996 -0.000002  0.000171      9     9
#  19997 -0.000009  0.000181      9     9
#  19998 -0.000004  0.000187      9     9
#  19999  0.000016  0.000182      9     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000258  0.000096      9     9
#  1      0.000243  0.000106      9     9
#  2      0.000215  0.000115      9     9
#  3      0.000192  0.000125      9     9
#  4      0.000180  0.000136      9     9
#  ...         ...       ...    ...   ...
#  19995  0.000218  0.000086      9     9
#  19996  0.000321  0.000099      9     9
#  19997  0.000404  0.000116      9     9
#  19998  0.000459  0.000134      9     9
#  19999  0.000488  0.000153      9     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0     -0.000159 -0.000054      9     9
#  1     -0.000045 -0.000038      9     9
#  2      0.000081 -0.000023      9     9
#  3      0.000191 -0.000012      9     9
#  4      0.000270 -0.000009      9     9
#  ...         ...       ...    ...   ...
#  19995  0.000333 -0.000084      9     9
#  19996  0.000378 -0.000054      9     9
#  19997  0.000419 -0.000027      9     9
#  19998  0.000444 -0.000013      9     9
#  19999  0.000446 -0.000011      9     9
#
#  [20000 rows x 4 columns],
#             EMG1      EMG2  class  user
#  0      0.000078 -0.000153      9     9
#  1      0.000088 -0.000146      9     9
#  2      0.000093 -0.000129      9     9
#  3      0.000099 -0.000110      9     9
#  4      0.000119 -0.000102      9     9
#  ...         ...       ...    ...   ...
#  19995  0.000120 -0.000106      9     9
#  19996  0.000138 -0.000116      9     9
#  19997  0.000143 -0.000125      9     9
#  19998  0.000125 -0.000127      9     9
#  19999  0.000090 -0.000123      9     9
#
#  [20000 rows x 4 columns]]

# %%
# Função para aplicar janelas deslizantes em um sinal de EMG
def sliding_window_emg(signal, window_size):
    windows = []
    for i in range(len(signal) - window_size + 1):
        window = signal[i:i + window_size]
        windows.append(window)
    return np.array(windows)

# Coluna a ser utilizada
emg_signal = df["EMG1"].values

# Parâmetros da janela deslizante
window_size = 100  # Tamanho da janela

# Aplicar janelas deslizantes no sinal de EMG
emg_windows = sliding_window_emg(emg_signal, window_size)

# Visualizar o sinal original e as janelas deslizantes
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(emg_signal, label='Sinal de EMG')
plt.title('Sinal de EMG a partir de Arquivo CSV')
plt.xlabel('Amostra')
plt.ylabel('Amplitude')
plt.legend()

plt.subplot(2, 1, 2)
plt.imshow(emg_windows, aspect='auto', cmap='viridis', extent=[0, len(emg_signal), 0, window_size])
plt.title('Janelas Deslizantes')
plt.xlabel('Amostra')
plt.ylabel('Índice da Janela')
plt.colorbar(label='Amplitude')
plt.tight_layout()

plt.show()

# %%
# Função para aplicar janelas deslizantes em um sinal de EMG
def sliding_window_emg(signal, window_size):
    windows = []
    for i in range(len(signal) - window_size + 1):
        window = signal[i:i + window_size]
        windows.append(window)
    return np.array(windows)

# Coluna a ser utilizada 
emg_signal = dataset1["EMG1"].values

# Parâmetros da janela deslizante
window_size = 200  # Tamanho da janela

# Aplicar janelas deslizantes no sinal de EMG
emg_windows = sliding_window_emg(emg_signal, window_size)

# Visualizar o sinal original e as janelas deslizantes
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(emg_signal, label='Sinal de EMG')
plt.title('Sinal de EMG a partir de Arquivo CSV')
plt.xlabel('Amostra')
plt.ylabel('Amplitude')
plt.legend()

plt.subplot(2, 1, 2)
plt.imshow(emg_windows, aspect='auto', cmap='viridis', extent=[0, len(emg_signal), 0, window_size])
plt.title('Janelas Deslizantes')
plt.xlabel('Amostra')
plt.ylabel('Índice da Janela')
plt.colorbar(label='Amplitude')
plt.tight_layout()

plt.show()

# %%
# Função para aplicar janelas deslizantes em um sinal de EMG
def sliding_window_emg(signal, window_size):
    windows = []
    for i in range(len(signal) - window_size + 1):
        window = signal[i:i + window_size]
        windows.append(window)
    return np.array(windows)

# Coluna a ser utilizada 
emg_signal = dataset3["EMG1"].values

# Parâmetros da janela deslizante
window_size = 300  # Tamanho da janela

# Aplicar janelas deslizantes no sinal de EMG
emg_windows = sliding_window_emg(emg_signal, window_size)

# Visualizar o sinal original e as janelas deslizantes
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(emg_signal, label='Sinal de EMG')
plt.title('Sinal de EMG a partir de Arquivo CSV')
plt.xlabel('Amostra')
plt.ylabel('Amplitude')
plt.legend()

plt.subplot(2, 1, 2)
plt.imshow(emg_windows, aspect='auto', cmap='viridis', extent=[0, len(emg_signal), 0, window_size])
plt.title('Janelas Deslizantes')
plt.xlabel('Amostra')
plt.ylabel('Índice da Janela')
plt.colorbar(label='Amplitude')
plt.tight_layout()

plt.show()

# %%
# Função para aplicar janelas deslizantes em um sinal de EMG
def sliding_window_emg(signal, window_size):
    windows = []
    for i in range(len(signal) - window_size + 1):
        window = signal[i:i + window_size]
        windows.append(window)
    return np.array(windows)


# Coluna a ser utilizada 
emg_signal = dataset1["EMG1"].values

# Parâmetros da janela deslizante
window_size = 1000  # Tamanho da janela

# Aplicar janelas deslizantes no sinal de EMG
emg_windows = sliding_window_emg(emg_signal, window_size)

# Normalizar os dados para a escala de cores
norm = mcolors.Normalize(vmin=emg_windows.min(), vmax=emg_windows.max())

# Visualizar o sinal original e as janelas deslizantes
plt.figure(figsize=(14, 6))

plt.subplot(2, 1, 1)
plt.plot(emg_signal, label='Sinal de EMG')
plt.title('Sinal de EMG a partir de Arquivo CSV')
plt.xlabel('Amostra')
plt.ylabel('Amplitude')
plt.legend()

plt.subplot(2, 1, 2)
plt.imshow(emg_windows, aspect='auto', cmap='viridis', extent=[0, len(emg_signal), 0, window_size], norm=norm)
plt.title('Janelas Deslizantes')
plt.xlabel('Amostra')
plt.ylabel('Índice da Janela')
plt.colorbar(label='Amplitude')
plt.tight_layout()

plt.show()

# %%
# Função para aplicar janelas deslizantes em um sinal de EMG
def sliding_window_emg(signal, window_size):
    windows = []
    for i in range(len(signal) - window_size + 1):
        window = signal[i:i + window_size]
        windows.append(window)
    return np.array(windows)


# Coluna a ser utilizada 
emg_signal = dataset1["EMG1"].values

# Parâmetros da janela deslizante
window_size = 200 # Tamanho da janela

# Aplicar janelas deslizantes no sinal de EMG
emg_windows = sliding_window_emg(emg_signal, window_size)

# Normalizar os dados para a escala de cores
norm = mcolors.Normalize(vmin=emg_windows.min(), vmax=emg_windows.max())

# Visualizar o sinal original e as janelas deslizantes
plt.figure(figsize=(20, 10))

plt.subplot(2, 1, 1)
plt.plot(emg_signal, label='Sinal de EMG')
plt.title('Sinal de EMG a partir de Arquivo CSV')
plt.xlabel('Amostra')
plt.ylabel('Amplitude')
plt.legend()

plt.subplot(2, 1, 2)
plt.imshow(emg_windows, aspect='auto', cmap='viridis', extent=[0, len(emg_signal), 0, window_size], norm=norm)
plt.title('Janelas Deslizantes')
plt.xlabel('Amostra')
plt.ylabel('Índice da Janela')
plt.colorbar(label='Amplitude')
plt.tight_layout()

plt.show()
