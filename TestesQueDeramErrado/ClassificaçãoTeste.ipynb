# %%
from google.colab import drive
drive.mount('/EMG_2Chs')
# Out:
# Mounted at /EMG_2Chs

# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

# %% [markdown]
# # Armazenando os dados em um dataset

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S1' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset1 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S2' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset2 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S3' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset3 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S4' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset4 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S5' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset5 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S6' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset6 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S7' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset7 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S8' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset8 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S9' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset9 = pd.concat(dataframes, ignore_index=True)

# %%
# Diretório onde estão as pastas de classificação
classification_directory = '/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10' # Coloque o caminho correto

# Lista para armazenar DataFrames de cada arquivo CSV
dataframes = []

# Loop pelas pastas de classificação
for classification_folder in os.listdir(classification_directory):
    classification_path = os.path.join(classification_directory, classification_folder)

    # Verifica se é uma pasta (ignora arquivos)
    if os.path.isdir(classification_path):
        # Loop pelos arquivos CSV na pasta de classificação
        for filename in os.listdir(classification_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(classification_path, filename)
                df = pd.read_csv(file_path)  # Lê o arquivo CSV como DataFrame

                # Adiciona o DataFrame à lista
                dataframes.append(df)

# Concatena todos os DataFrames em um único DataFrame "dataset"
dataset10 = pd.concat(dataframes, ignore_index=True)

# %%
dataset9
# Out:
#              EMG1      EMG2  class  user
# 0        0.000556  0.000319      4     8
# 1        0.000516  0.000388      4     8
# 2        0.000469  0.000418      4     8
# 3        0.000415  0.000416      4     8
# 4        0.000354  0.000392      4     8
# ...           ...       ...    ...   ...
# 1199995 -0.000086  0.000306      0     8
# 1199996 -0.000073  0.000309      0     8
# 1199997 -0.000063  0.000306      0     8
# 1199998 -0.000056  0.000299      0     8
# 1199999 -0.000048  0.000289      0     8
#
# [1200000 rows x 4 columns]

# %%
for i in range(1, 11):
  datastring = "dataset" + str(i)
  print(datastring)
# Out:
# dataset1
# dataset2
# dataset3
# dataset4
# dataset5
# dataset6
# dataset7
# dataset8
# dataset9
# dataset10

# %%
# Suponha que você tenha seus DataFrames como dataset1, dataset2, ..., dataset10

# Crie uma lista com todos os DataFrames
dataframes = [dataset1, dataset2, dataset3, dataset4, dataset5, dataset6, dataset7, dataset8, dataset9, dataset10]

# Concatene todos os DataFrames em um único DataFrame
dataset_final = pd.concat(dataframes, ignore_index=True)

# O argumento 'ignore_index=True' redefinirá os índices do DataFrame resultante

# Agora, 'dataset_final' conterá todos os dados dos DataFrames concatenados em um único DataFrame.

dataset_final.head()
# Out:
#        EMG1      EMG2 class user
# 0  0.000225  0.000439     6    1
# 1  0.000745  0.000475     6    1
# 2  0.001311  0.000511     6    1
# 3  0.001803  0.000538     6    1
# 4  0.002117  0.000554     6    1

# %%
tamanho = dataset_final.shape  # Retorna uma tupla (número de linhas, número de colunas)
print("Número de Linhas:", tamanho[0])
print("Número de Colunas:", tamanho[1])
# Out:
# Número de Linhas: 12020000
# Número de Colunas: 4

# %%
dataset_final
# Out:
#               EMG1      EMG2 class user
# 0         0.000225  0.000439     6    1
# 1         0.000745  0.000475     6    1
# 2         0.001311  0.000511     6    1
# 3         0.001803  0.000538     6    1
# 4         0.002117  0.000554     6    1
# ...            ...       ...   ...  ...
# 12019995 -0.000279 -0.000633     0    9
# 12019996 -0.000234 -0.000595     0    9
# 12019997 -0.000212 -0.000512     0    9
# 12019998 -0.000220 -0.000415     0    9
# 12019999 -0.000250 -0.000329     0    9
#
# [12020000 rows x 4 columns]

# %%
# Embaralhe o DataFrame
data = dataset_final.sample(frac=1, random_state=42).reset_index(drop=True)

# O argumento 'frac=1' significa que você deseja amostrar 100% das linhas, ou seja, embaralhar todas as linhas.
# O argumento 'random_state' é usado para garantir que o embaralhamento seja reproduzível.

# Agora, 'data' conterá os dados embaralhados.

# %%
tt = pd.read_csv('/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/T-R/T-R6.csv')
tt.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000227 -0.000074      8     9
# 1  0.000187 -0.000065      8     9
# 2  0.000167 -0.000066      8     9
# 3  0.000164 -0.000073      8     9
# 4  0.000163 -0.000080      8     9

# %%
hc1 = pd.read_csv('/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/HC/HC-6.csv')
hc1.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000199 -0.000151      0     9
# 1  0.000197 -0.000103      0     9
# 2  0.000183 -0.000060      0     9
# 3  0.000150 -0.000031      0     9
# 4  0.000098 -0.000023      0     9

# %%
tr = pd.read_csv('/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/T-R/T-R6.csv')
tr.head(100)
# Out:
#         EMG1      EMG2  class  user
# 0   0.000227 -0.000074      8     9
# 1   0.000187 -0.000065      8     9
# 2   0.000167 -0.000066      8     9
# 3   0.000164 -0.000073      8     9
# 4   0.000163 -0.000080      8     9
# ..       ...       ...    ...   ...
# 95 -0.000012  0.000432      8     9
# 96 -0.000050  0.000440      8     9
# 97 -0.000094  0.000390      8     9
# 98 -0.000133  0.000293      8     9
# 99 -0.000159  0.000172      8     9
#
# [100 rows x 4 columns]

# %%
tr = pd.read_csv('/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S9/HC/HC-1.csv')
tr.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000178 -0.000261      0     8
# 1  0.000211 -0.000318      0     8
# 2  0.000229 -0.000373      0     8
# 3  0.000236 -0.000418      0     8
# 4  0.000240 -0.000442      0     8

# %%
hc = pd.read_csv('/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S8/HC/HC-1.csv')
hc.head()
# Out:
#        EMG1      EMG2  class  user
# 0  0.000028  0.000749      0     7
# 1  0.000033  0.000750      0     7
# 2  0.000027  0.000719      0     7
# 3  0.000028  0.000648      0     7
# 4  0.000044  0.000539      0     7

# %%
tt.iloc[0][3]
# Out:
# 9.0

# %%
hc = pd.read_csv('/EMG_2Chs/MyDrive/Colab Notebooks/EMG_2Chs/EMG-S10/HC/HC-1.csv')
hc.head()
# Out:
#        EMG1      EMG2  class  user
# 0 -0.000170  0.000204      0     9
# 1 -0.000141  0.000134      0     9
# 2 -0.000146  0.000081      0     9
# 3 -0.000182  0.000059      0     9
# 4 -0.000234  0.000079      0     9

# %% [markdown]
# # Helper Functions (Funções auxiliares)

# %%
def onehot_encode(df, column):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=column)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
def preprocess_inputs(df, target='class'):
    df = df.copy()

    # One-hot encode whichever target column is not being used
    targets = ['class', 'user']
    targets.remove(target)
    df = onehot_encode(df, column=targets[0])

    # Split df into X and y
    y = df[target].copy()
    X = df.drop(target, axis=1)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

    # Scale X with a standard scaler
    scaler = StandardScaler()
    scaler.fit(X_train)

    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

    return X_train, X_test, y_train, y_test

# %%
def build_model(num_classes=10):

    inputs = tf.keras.Input(shape=(X_train.shape[1],))
    x = tf.keras.layers.Dense(128, activation='relu')(inputs)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# # Predicting Hand Movement Class (Aula de previsão de movimento da mão)

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data, target='class')
# Out:
# <ipython-input-27-b1b73a166137>:3: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   dummies = pd.get_dummies(df[column], prefix=column)

# %%
y_train
# Out:
# 6513728     9
# 666337      0
# 11354949    3
# 7284405     6
# 10945244    1
#            ..
# 1241052     3
# 11552066    2
# 4222334     1
# 8666477     9
# 4967934     0
# Name: class, Length: 8414000, dtype: object

# %%
y_train.value_counts()
# Out:
# 0    868938
# 7    840681
# 8    840481
# 9    840271
# 4    840015
# 2    839803
# 3    839775
# 5    839592
# 1    839316
# 6    825128
# Name: class, dtype: int64

# %%
X_train.value_counts()
# Out:
# EMG1       EMG2       user_0     user_1     user_2    user_3     user_4     user_5     user_6     user_7     user_8     user_9
# -0.090544  -0.087516  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112  -0.333146   3.002939  -0.339162    5
#  0.142515  -0.056582  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112  -0.333146   3.002939  -0.339162    5
#  0.085855  -0.129045  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112  -0.333146   3.002939  -0.339162    5
#  0.032824  -0.428221  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112  -0.333146  -0.333007   2.948446    5
# -0.055097  -0.111671  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112  -0.333146   3.002939  -0.339162    5
#                                                                                                                                     ..
# -0.181813  -0.214645  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112   3.001689  -0.333007  -0.339162    1
#            -0.217611  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948   3.001994  -0.333146  -0.333007  -0.339162    1
#            -0.219306  -0.329824  -0.332892  -0.33312  -0.333035  -0.333045  -0.332948  -0.333112  -0.333146   3.002939  -0.339162    1
#            -0.220578  -0.329824  -0.332892  -0.33312  -0.333035   3.002600  -0.332948  -0.333112  -0.333146  -0.333007  -0.339162    1
#  8.498898   0.503209  -0.329824  -0.332892  -0.33312   3.002683  -0.333045  -0.332948  -0.333112  -0.333146  -0.333007  -0.339162    1
# Length: 8244450, dtype: int64

# %%
X_train.shape[1]
# Out:
# 12

# %%
print("Dimensões de X_train:", X_train.shape)
print("Dimensões de y_train:", y_train.shape)
# Out:
# Dimensões de X_train: (8414000, 12)
# Dimensões de y_train: (8414000,)

# %%
unique_classes = pd.unique(y_train)
print("Classes únicas:", unique_classes)
# Out:
# Classes únicas: [9 0 3 6 1 7 8 2 5 4]

# %%
# Converter y_train para o tipo correto
y_train = tf.convert_to_tensor(y_train, dtype=tf.int32)

# %%
"""class_model = build_model(num_classes=10)

class_history = class_model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)"""
# Out:
# "class_model = build_model(num_classes=10)\n\nclass_history = class_model.fit(\n    X_train,\n    y_train,\n    validation_split=0.2,\n    batch_size=32,\n    epochs=5,\n    callbacks=[\n        tf.keras.callbacks.EarlyStopping(\n            monitor='val_loss',\n            patience=3,\n            restore_best_weights=True\n        )\n    ]\n)"

# %% [markdown]
# # Classificando os dados

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=7, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 7 folds for each of 20 candidates, totalling 140 fits

# %% [markdown]
# **Testando os códigos**

# %% [markdown]
# os testes que deram errado

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
import numpy as np

# Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(-3, -9, num=20)}  # Reduzindo o número de valores

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-fceff35aa5b5> in <cell line: 6>()
#       4
#       5 # Certifique-se de que seus rótulos de classe estejam no formato adequado (array NumPy de inteiros)
# ----> 6 y_train = y_train.astype(int)
#       7 y_test = y_test.astype(int)
#       8
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in __getattr__(self, name)
#     422                 "tolist", "data"}:
#     423       # TODO(wangpeng): Export the enable_numpy_behavior knob
# --> 424       raise AttributeError(
#     425           f"{type(self).__name__} object has no attribute '{name}'. " + """
#     426         If you are looking for numpy-related methods, please run the following:
#
# AttributeError: EagerTensor object has no attribute 'astype'.
#         If you are looking for numpy-related methods, please run the following:
#         from tensorflow.python.ops.numpy_ops import np_config
#         np_config.enable_numpy_behavior()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
import numpy as np

# Defina a grade de hiperparâmetros para alpha
param_grid = {'var_smoothing': np.logspace(0,-9, num=100)}

# Crie o modelo Naive Bayes
nb_model = GaussianNB()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhor valor de alpha:", grid_search.best_params_['var_smoothing'])

# Obtenha o melhor modelo treinado com os melhores hiperparâmetros
best_nb_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_nb_model.score(X_test, y_test)
print(f'Acurácia no conjunto de teste: {accuracy:.2f}')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 678, in _fit_and_score
#     X_train, y_train = _safe_split(estimator, X, y, train)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/metaestimators.py", line 236, in _safe_split
#     y_subset = _safe_indexing(y, indices)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/__init__.py", line 356, in _safe_indexing
#     return _array_indexing(X, indices, indices_dtype, axis=axis)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/__init__.py", line 185, in _array_indexing
#     return array[key] if axis == 0 else array[:, key]
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py", line 926, in _check_index
#     raise TypeError(_SLICE_TYPE_ERROR + ", got {!r}".format(idx))
# TypeError: Only integers, slices (`:`), ellipsis (`...`), tf.newaxis (`None`) and scalar tf.int32/tf.int64 tensors are valid indices, got memmap([      0,       1,       2, ..., 8413997, 8413998, 8413999])
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6c62a60503c4> in <cell line: 15>()
#      13
#      14 # Ajuste o modelo aos dados
# ---> 15 grid_search.fit(X_train, y_train)
#      16
#      17 # Exiba os melhores hiperparâmetros encontrados
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1950         next(output)
#    1951
# -> 1952         return output if self.return_generator else list(output)
#    1953
#    1954     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1593
#    1594             with self._backend.retrieval_context():
# -> 1595                 yield from self._retrieve()
#    1596
#    1597         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1697             # worker traceback.
#    1698             if self._aborting:
# -> 1699                 self._raise_error_fast()
#    1700                 break
#    1701
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _raise_error_fast(self)
#    1732         # called directly or if the generator is gc'ed.
#    1733         if error_job is not None:
# -> 1734             error_job.get_result(self.timeout)
#    1735
#    1736     def _warn_exit_early(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in get_result(self, timeout)
#     734             # callback thread, and is stored internally. It's just waiting to
#     735             # be returned.
# --> 736             return self._return_or_raise()
#     737
#     738         # For other backends, the main thread needs to run the retrieval step.
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _return_or_raise(self)
#     752         try:
#     753             if self.status == TASK_ERROR:
# --> 754                 raise self._result
#     755             return self._result
#     756         finally:
#
# TypeError: Only integers, slices (`:`), ellipsis (`...`), tf.newaxis (`None`) and scalar tf.int32/tf.int64 tensors are valid indices, got memmap([      0,       1,       2, ..., 8413997, 8413998, 8413999])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import numpy as np
import pandas as pd

# Suponha que você tenha identificado que as classes 1 e 2 são semelhantes
# Crie um novo conjunto de dados combinando essas duas classes
class_1_data = dataset_final[dataset_final['class'] == 1]
class_2_data = dataset_final[dataset_final['class'] == 2]
combined_data = pd.concat([class_1_data, class_2_data], ignore_index=True)

# Separe as características (X) e os rótulos (y) para o novo conjunto de dados combinado
X = combined_data.drop('class', axis=1)
y = combined_data['class']

# Divida o conjunto de dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Escala as características
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Crie um modelo SVM binário
svm_model = SVC(kernel='linear', C=1)

# Treine o modelo SVM
svm_model.fit(X_train_scaled, y_train)

# Avalie o modelo no conjunto de teste
accuracy = svm_model.score(X_test_scaled, y_test)
print(f'Acurácia do modelo SVM: {accuracy:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-e27385ecee90> in <cell line: 29>()
#      27
#      28 # Treine o modelo SVM
# ---> 29 svm_model.fit(X_train_scaled, y_train)
#      30
#      31 # Avalie o modelo no conjunto de teste
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     199             )
#     200
# --> 201         y = self._validate_targets(y)
#     202
#     203         sample_weight = np.asarray(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     743     def _validate_targets(self, y):
#     744         y_ = column_or_1d(y, warn=True)
# --> 745         check_classification_targets(y)
#     746         cls, y = np.unique(y_, return_inverse=True)
#     747         self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     216         "multilabel-sequences",
#     217     ]:
# --> 218         raise ValueError("Unknown label type: %r" % y_type)
#     219
#     220
#
# ValueError: Unknown label type: 'unknown'

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# Obtenha a lista de classes únicas no seu conjunto de dados
classes_unicas = dataset_final['class'].unique()

# Defina a grade de hiperparâmetros que deseja otimizar
param_grid = {
    'C': [0.1, 1, 10],                # Parâmetro de regularização
    'kernel': ['linear', 'rbf'],      # Tipo de kernel
    'gamma': [0.1, 1, 'scale', 'auto']  # Coeficiente do kernel (para kernel rbf)
}

# Itere sobre as classes e treine um modelo SVM para cada classe
for classe in classes_unicas:
    # Filtrar o conjunto de dados para a classe atual
    data_classe = dataset_final[dataset_final['class'] == classe]

    # Separe as características (X) e os rótulos (y) para a classe
    X = data_classe.drop('class', axis=1)
    y = data_classe['class']

    # Verifique se há pelo menos duas classes distintas na classe atual
    if len(y.unique()) < 2:
        print(f"Classe {classe} não contém pelo menos duas classes distintas para treinamento.")
        continue

    # Verifique se os rótulos são do tipo inteiro ou categórico
    if not y.dtype in [int, str]:
        print(f"Classe {classe} contém rótulos em um formato não reconhecido.")
        continue

    # Crie o modelo SVM
    svm_model = SVC()

    # Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
    grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

    # Ajuste o modelo aos dados
    grid_search.fit(X, y)

    # Exiba os melhores hiperparâmetros encontrados para esta classe
    print(f"Classe: {classe}")
    print("Melhores hiperparâmetros encontrados:")
    print(grid_search.best_params_)

    # Obtenha o melhor modelo treinado para esta classe
    best_svm_model = grid_search.best_estimator_

    # Avalie o modelo no conjunto de teste (você pode dividir seus dados em treinamento e teste para avaliação)
    # accuracy = best_svm_model.score(X_test, y_test)
    # print(f"Acurácia no conjunto de teste: {accuracy:.2f}")

    # Plote ou imprima gráficos aqui para análise (exemplo com matplotlib)
    # plt.scatter(X, y, c=best_svm_model.predict(X), cmap='viridis')
    # plt.xlabel('Característica 1')
    # plt.ylabel('Característica 2')
    # plt.title(f"Classe: {classe}")
    # plt.show()
# Out:
# Classe 6 não contém pelo menos duas classes distintas para treinamento.
# Classe 3 não contém pelo menos duas classes distintas para treinamento.
# Classe 2 não contém pelo menos duas classes distintas para treinamento.
# Classe 5 não contém pelo menos duas classes distintas para treinamento.
# Classe 7 não contém pelo menos duas classes distintas para treinamento.
# Classe 4 não contém pelo menos duas classes distintas para treinamento.
# Classe 9 não contém pelo menos duas classes distintas para treinamento.
# Classe 8 não contém pelo menos duas classes distintas para treinamento.
# Classe 1 não contém pelo menos duas classes distintas para treinamento.
# Classe 0 não contém pelo menos duas classes distintas para treinamento.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# Defina os valores possíveis para os hiperparâmetros que deseja otimizar
param_grid = {
    'C': [0.1, 1, 10],                # Parâmetro de regularização
    'kernel': ['linear', 'rbf'],      # Tipo de kernel
    'gamma': [0.1, 1, 'scale', 'auto']  # Coeficiente do kernel (para kernel rbf)
}

# Crie o modelo SVM
svm_model = SVC()

# Crie um objeto GridSearchCV para pesquisa em grade com validação cruzada
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Ajuste o modelo aos dados
grid_search.fit(X_train, y_train)

# Exiba os melhores hiperparâmetros encontrados
print("Melhores hiperparâmetros encontrados:")
print(grid_search.best_params_)

# Obtenha o melhor modelo treinado
best_svm_model = grid_search.best_estimator_

# Avalie o modelo no conjunto de teste
accuracy = best_svm_model.score(X_test, y_test)
print(f"Acurácia no conjunto de teste: {accuracy:.2f}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-67314aef79cb> in <cell line: 18>()
#      16
#      17 # Ajuste o modelo aos dados
# ---> 18 grid_search.fit(X_train, y_train)
#      19
#      20 # Exiba os melhores hiperparâmetros encontrados
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850
# --> 851                 _warn_or_raise_about_fit_failures(out, self.error_score)
#     852
#     853                 # For callable self.scoring, the return type is only know after
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _warn_or_raise_about_fit_failures(results, error_score)
#     365                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     366             )
# --> 367             raise ValueError(all_fits_failed_message)
#     368
#     369         else:
#
# ValueError:
# All the 120 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py", line 201, in fit
#     y = self._validate_targets(y)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py", line 745, in _validate_targets
#     check_classification_targets(y)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py", line 218, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

# Crie um objeto LabelEncoder
le = LabelEncoder()

# Ajuste o LabelEncoder aos seus rótulos
le.fit(y_train)

# Transforme os seus rótulos usando o LabelEncoder
y_train_encoded = le.transform(y_train)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# Importe o conjunto de dados
#dataset = pd.read_csv("dataset_final.csv")

# Divida o conjunto de dados em um conjunto de treinamento e um conjunto de teste
X_train, X_test, y_train, y_test = train_test_split(dataset_final.drop("class", axis=1), dataset_final["class"], test_size=0.2)

# Treine um modelo SVM
model = SVC(kernel="linear", C=1)
model.fit(X_train, y_train_encoded)

# Avalie o modelo
score = model.score(X_test, y_test)
print(score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-5897d656f180> in <cell line: 13>()
#      11 # Treine um modelo SVM
#      12 model = SVC(kernel="linear", C=1)
# ---> 13 model.fit(X_train, y_train_encoded)
#      14
#      15 # Avalie o modelo
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     190             check_consistent_length(X, y)
#     191         else:
# --> 192             X, y = self._validate_data(
#     193                 X,
#     194                 y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1122     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1123
# -> 1124     check_consistent_length(X, y)
#    1125
#    1126     return X, y
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [9616000, 8414000]
