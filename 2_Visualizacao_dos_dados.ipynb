# %%
import matplotlib.pyplot as plt

# %%
# %run "./1_Organizacao_dos_Dados.ipynb"
# Out:
# C:/Users/admin/Desktop/EMG_IA_LIT GITHUB/EMG_IA_LIT/EMG-LIT/EMG-S1

# %% [markdown]
# # Visualizando gráficos

# %% [markdown]
# ## HC

# %%
# Supondo que seu DataFrame seja df_HC_1
# Substitua 'EMG1' e 'EMG2' pelos nomes reais das colunas
coluna_emg1 = 'EMG1'
coluna_emg2 = 'EMG2'

##########
### HC_1
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_HC_1.index, df_HC_1[coluna_emg2], label='EMG2')
plt.plot(df_HC_1.index, df_HC_1[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [HC_1]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### HC_2
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_HC_2.index, df_HC_2[coluna_emg2], label='EMG2')
plt.plot(df_HC_2.index, df_HC_2[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [HC_2]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### HC_3
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_HC_3.index, df_HC_3[coluna_emg2], label='EMG2')
plt.plot(df_HC_3.index, df_HC_3[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [HC_3]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### HC_4
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_HC_4.index, df_HC_4[coluna_emg2], label='EMG2')
plt.plot(df_HC_4.index, df_HC_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [HC_4]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### HC_5
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_HC_4.index, df_HC_4[coluna_emg2], label='EMG2')
plt.plot(df_HC_4.index, df_HC_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [HC_5]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### HC_6
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_HC_4.index, df_HC_4[coluna_emg2], label='EMG2')
plt.plot(df_HC_4.index, df_HC_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [HC_6]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## I

# %%
# Supondo que seu DataFrame seja df_I_1
# Substitua 'EMG1' e 'EMG2' pelos nomes reais das colunas
coluna_emg1 = 'EMG1'
coluna_emg2 = 'EMG2'

##########
### I_1
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_I_1.index, df_I_1[coluna_emg2], label='EMG2')
plt.plot(df_I_1.index, df_I_1[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [I_1]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### I_2
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_I_2.index, df_I_2[coluna_emg2], label='EMG2')
plt.plot(df_I_2.index, df_I_2[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [I_2]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### I_3
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_I_3.index, df_I_3[coluna_emg2], label='EMG2')
plt.plot(df_I_3.index, df_I_3[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [I_3]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### I_4
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_I_4.index, df_I_4[coluna_emg2], label='EMG2')
plt.plot(df_I_4.index, df_I_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [I_4]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### I_5
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_I_4.index, df_I_4[coluna_emg2], label='EMG2')
plt.plot(df_I_4.index, df_I_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [I_5]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### I_6
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_I_4.index, df_I_4[coluna_emg2], label='EMG2')
plt.plot(df_I_4.index, df_I_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [I_6]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 11
#       6 ##########
#       7 ### I_1
#       8 ##########
#       9 # Plotar os valores EMG1 e EMG2 ao longo do tempo
#      10 plt.figure(figsize=(10, 6))
# ---> 11 plt.plot(df_I_1.index, df_I_1[coluna_emg2], label='EMG2')
#      12 plt.plot(df_I_1.index, df_I_1[coluna_emg1], label='EMG1')
#      14 # Adicionar rótulos e título
#
# NameError: name 'df_I_1' is not defined

# %% [markdown]
# ## L

# %%
# Supondo que seu DataFrame seja df_L_1
# Substitua 'EMG1' e 'EMG2' pelos nomes reais das colunas
coluna_emg1 = 'EMG1'
coluna_emg2 = 'EMG2'

##########
### L_1
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_L_1.index, df_L_1[coluna_emg2], label='EMG2')
plt.plot(df_L_1.index, df_L_1[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [L_1]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### L_2
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_L_2.index, df_L_2[coluna_emg2], label='EMG2')
plt.plot(df_L_2.index, df_L_2[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [L_2]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### L_3
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_L_3.index, df_L_3[coluna_emg2], label='EMG2')
plt.plot(df_L_3.index, df_L_3[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [L_3]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### L_4
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_L_4.index, df_L_4[coluna_emg2], label='EMG2')
plt.plot(df_L_4.index, df_L_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [L_4]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### L_5
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_L_4.index, df_L_4[coluna_emg2], label='EMG2')
plt.plot(df_L_4.index, df_L_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [L_5]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### L_6
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_L_4.index, df_L_4[coluna_emg2], label='EMG2')
plt.plot(df_L_4.index, df_L_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [L_6]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## R

# %%
# Supondo que seu DataFrame seja df_R_1
# Substitua 'EMG1' e 'EMG2' pelos nomes reais das colunas
coluna_emg1 = 'EMG1'
coluna_emg2 = 'EMG2'

##########
### R_1
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_R_1.index, df_R_1[coluna_emg2], label='EMG2')
plt.plot(df_R_1.index, df_R_1[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [R_1]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### R_2
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo 
plt.figure(figsize=(10, 6))
plt.plot(df_R_2.index, df_R_2[coluna_emg2], label='EMG2')
plt.plot(df_R_2.index, df_R_2[coluna_emg1], label='EMG1')

# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [R_2]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### R_3
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_R_3.index, df_R_3[coluna_emg2], label='EMG2')
plt.plot(df_R_3.index, df_R_3[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [R_3]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### R_4
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_R_4.index, df_R_4[coluna_emg2], label='EMG2')
plt.plot(df_R_4.index, df_R_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [R_4]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### R_5
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_R_4.index, df_R_4[coluna_emg2], label='EMG2')
plt.plot(df_R_4.index, df_R_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [R_5]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

##########
### R_6
##########
# Plotar os valores EMG1 e EMG2 ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(df_R_4.index, df_R_4[coluna_emg2], label='EMG2')
plt.plot(df_R_4.index, df_R_4[coluna_emg1], label='EMG1')


# Adicionar rótulos e título
plt.xlabel('Tempo')
plt.ylabel('Valores EMG')
plt.title('Valores EMG ao Longo do Tempo [R_6]')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Mínimo e Máximo

# %%
# Substitua 'EMG1' e 'EMG2' pelos nomes reais das colunas
coluna_emg1 = 'EMG1'
coluna_emg2 = 'EMG2'

# Encontrar o valor mínimo e máximo para EMG1
min_emg1 = df_HC_1[coluna_emg1].min()
max_emg1 = df_HC_1[coluna_emg1].max()

# Encontrar o valor mínimo e máximo para EMG2
min_emg2 = df_HC_1[coluna_emg2].min()
max_emg2 = df_HC_1[coluna_emg2].max()

# Exibir os resultados
print(f"Valor mínimo de {coluna_emg1}: {min_emg1}")
print(f"Valor máximo de {coluna_emg1}: {max_emg1}")
print(f"Valor mínimo de {coluna_emg2}: {min_emg2}")
print(f"Valor máximo de {coluna_emg2}: {max_emg2}")
# Out:
# Valor mínimo de EMG1: -0.001229651
# Valor máximo de EMG1: 0.001803079
# Valor mínimo de EMG2: -0.001649887
# Valor máximo de EMG2: 0.003183397
